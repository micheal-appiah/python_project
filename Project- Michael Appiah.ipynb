# %% [markdown]
# # Index Number: 10961589
# # Name:Michael Appiah
# # Department:Computer Engineering

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_palette("magma")
sns.set_style('darkgrid')

# %%
data=pd.read_csv('data.csv')
data
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data.isnull()
# Out:
#          ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     False          False             False        False           False
# 1     False          False             False        False           False
# 2     False          False             False        False           False
# 3     False          False             False        False           False
# 4     False          False             False        False           False
# ...     ...            ...               ...          ...             ...
# 1596  False          False             False        False           False
# 1597  False          False             False        False           False
# 1598  False          False             False        False           False
# 1599  False          False             False        False           False
# 1600  False          False             False        False           False
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density     pH  \
# ...

# %%
data.isnull().sum()
# Out:
# ID                      0
# fixed acidity           1
# volatile acidity        0
# citric acid             1
# residual sugar          0
# chlorides               3
# free sulfur dioxide     1
# total sulfur dioxide    1
# density                 1
# pH                      1
# sulphates               0
# alcohol                 0
# quality                 1
# dtype: int64

# %% [markdown]
# ### Replacing null values in each column with mean of each column and why?

# %%
eachcolumn=['fixed acidity','citric acid','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','quality']

# %%
for column in eachcolumn:
    data[column].fillna(data[column].mean(),inplace=True)

# %% [markdown]
# When data analysis involves missing values, a common technique is to substitute null values with the mean of the column. Removing rows with missing values can result in a loss of information and a decrease in sample size, which can negatively impact the accuracy and representativeness of the analysis. To retain the sample size and provide a reasonable estimate of the missing data, we can replace null values with the mean of the column. However, this approach assumes that the missing values are randomly distributed and the data is normally distributed. If the missing values are not randomly distributed or the data is not normally distributed, this approach may not be suitable for providing an accurate representation of the missing data. In such instances, alternative techniques such as interpolation, imputation, or eliminating rows/columns may be more appropriate.

# %%
data.isnull().sum()
# Out:
# ID                      0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# ### There are no duplicate in the dataset

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Statistical Inferences Of Entire Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    1601 non-null   int64
#  1   fixed acidity         1601 non-null   float64
#  2   volatile acidity      1601 non-null   float64
#  3   citric acid           1601 non-null   float64
#  4   residual sugar        1601 non-null   float64
#  5   chlorides             1601 non-null   float64
#  6   free sulfur dioxide   1601 non-null   float64
#  7   total sulfur dioxide  1601 non-null   float64
#  8   density               1601 non-null   float64
#  9   pH                    1601 non-null   float64
#  10  sulphates             1601 non-null   float64
#  11  alcohol               1601 non-null   float64
#  12  quality               1601 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 162.7 KB

# %%
data.describe()
# Out:
#                 ID  fixed acidity  volatile acidity  citric acid  \
# count  1601.000000    1601.000000       1601.000000  1601.000000
# mean    801.000000       8.319875          0.527742     0.271175
# std     462.313206       1.739495          0.178981     0.194684
# min       1.000000       4.600000          0.120000     0.000000
# 25%     401.000000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1201.000000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual sugar    chlorides  free sulfur dioxide  total sulfur dioxide  \
# count     1601.000000  1601.000000          1601.000000           1601.000000
# mean         2.538445     0.087487            15.886875             46.520000
# std          1.409138     0.047032            10.455218             32.967416
# ...

# %% [markdown]
# ### Histograms of the each column showing the characteristics of each column

# %%
clear_id=data.drop('ID', axis = 1)
clear_id.hist(figsize=(12, 10))
# Out:
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
#        [<Axes: title={'center': 'total sulfur dioxide'}>,
#         <Axes: title={'center': 'density'}>,
#         <Axes: title={'center': 'pH'}>],
#        [<Axes: title={'center': 'sulphates'}>,
#         <Axes: title={'center': 'alcohol'}>,
#         <Axes: title={'center': 'quality'}>]], dtype=object)

# %% [markdown]
# ###  A chart that displays the levels of quality for the different columns present in a dataset.

# %%
eachcolumn=['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']

# %%
for column in eachcolumn:
    plt.title(f'{column} against Quality')
    sns.barplot(x='quality',y=column, data=data, palette=('mako'))
    plt.figure(figsize=(12,10))
    plt.show()

# %% [markdown]
# ### A graphical representation of all acids against pH

# %%
acids=['fixed acidity','volatile acidity','citric acid']

# %%
for acid in acids:
    plt.title(f'A Relation between The pH and {acid}' )
    sns.scatterplot(x=acid , y='pH',data=data )
    plt.figure(figsize=(12,10))
    plt.show()

# %%
for i, column in enumerate(data.columns):
    if column not in ['ID', 'quality']:
        column_mean = data[column].mean()

        # Creating a boolean series based on condition
        compared_column_mean = data[column] < column_mean

        # Defining labels and explode values
        labels = ['Above Mean', 'Below Mean']
        explode = [0.1, 0]

        # Creating pie chart for each column
        sns.color_palette('crest',as_cmap=True)
        plt.pie(compared_column_mean.value_counts(), explode=explode, labels=labels, shadow=True)
        plt.title(f'{column} values ')

        plt.show()

# %% [markdown]
# ### Correlation Of The Data Using Heat Map

# %%
corr_matrix=data.corr()
sns.heatmap(corr_matrix,annot=True,cmap='coolwarm',annot_kws={"size":7})

plt.figure(figsize=(20,30))
plt.show()

# %% [markdown]
# ## Showing hidden inferences
# <hr></hr>
#
#
# ### Z-Scores and Outliers
# The z-score indicates how many standard deviations a particular data point is distant from the mean of the distribution.
#
# An outlier is a data point that lies far beyond the range of other data points. A popular technique for detecting outliers involves setting a threshold of 3 standard deviations.

# %%
for column in data.columns:
    if column != 'ID' :
    #Calculating the z-scores for each data point of each column
       z_scores = (data[column] - data[column].mean()) / data[column].std()
    #output below is all z_scores values for each column
       print(z_scores)

     #outliers are identified using a threshold of 3 standard deviations
       outliers = data[abs(z_scores) > 3]
# Out:
# 0      -0.528817
# 1      -0.298865
# 2      -0.298865
# 3       1.655725
# 4      -0.528817
#           ...
# 1596   -1.391137
# 1597   -1.161185
# 1598   -1.391137
# 1599   -1.333649
# 1600   -0.643793
# Name: fixed acidity, Length: 1601, dtype: float64
# 0       0.962436
# 1       1.968129
# 2       1.297667
# 3      -1.384179
# 4       0.962436
#           ...
# 1596    0.124359
# 1597   -0.099128
# 1598    0.655141
# 1599   -1.216564
# 1600   -0.769590
# Name: volatile acidity, Length: 1601, dtype: float64
# 0      -1.392900
# 1      -1.392900
# 2      -1.187439
# 3       1.483560
# 4      -1.392900
#           ...
# 1596   -0.879247
# 1597   -0.725151
# 1598   -0.776516
# 1599    1.021272
# 1600    0.867176
# Name: citric acid, Length: 1601, dtype: float64
# 0      -0.453075
# 1       0.043683
# 2      -0.169213
# 3      -0.453075
# 4      -0.453075
#           ...
# 1596   -0.240179
# 1597   -0.169213
# 1598   -0.382109
# 1599    0.753337
# 1600    0.043683
# ...

# %%
outliers
# Out:
#         ID  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 459    460           11.6             0.580         0.66            2.20
# 517    518           10.4             0.610         0.49            2.10
# 690    691            7.4             1.185         0.00            4.25
# 832    833           10.4             0.440         0.42            1.50
# 899    900            8.3             1.020         0.02            3.40
# 1299  1300            7.6             1.580         0.00            2.10
# 1374  1375            6.8             0.815         0.00            1.20
# 1469  1470            7.3             0.980         0.05            2.10
# 1478  1479            7.1             0.875         0.05            5.70
# 1506  1507            6.7             0.760         0.02            1.80
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 459       0.074                 10.0                  47.0  1.00080  3.25
# ...

# %%
for column in outliers.columns:
    if column != 'ID':
        plt.title(f'Outliers in {column}')
        plt.xlabel('Range')
        
        sns.scatterplot(outliers[column])
        plt.show()
